# %%
'''<<-----------------------------------------------------------------SEASOON_15--------------------------------------------------------------->>'''
'''1.Write a Python function called get_song_duration_per_minute that divides the total duration of a Spotify playlist (in minutes) by the number of songs, 
and handles the case where the number of songs is zero using try, except, and finally blocks.'''
total_duration = 180
number_songs = 15
try :
    average_duration = total_duration/number_songs
    print(f"The average duration of the spotify is :-",average_duration)
except ZeroDivisionError:
    print("The number of songs cannot be zero")
finally :
    print("program execution completed")
# Out:
# The average duration of the spotify is :- 12.0
# program execution completed

# %%
'''2.Build a Flipkart-style price-per-item calculator: take total cart amount and item count as input, perform division, and use try-except to catch and 
display a user-friendly message if the item count is zero.'''
try :
    total_cart_amount = int(input("enter your total cart amount"))
    iteam_count = int(input("enter your total count"))
    price_per_iteam = total_cart_amount/iteam_count
    print("The price per iteam is :--",price_per_iteam)

except ZeroDivisionError:
    print("sorry !!!,you need to give more then 1 item")
finally:
    print("Thankyou for using the flipcart price calculator")

# %%
'''3.Create a Paytm cashback calculator that asks for total spend and number of offers applied, then divides spend by offers to show average cashback per 
offer. If the number of offers is zero, raise a custom exception called NoOffersApplied and display a custom error message.
<br><br><em><strong>Hint:</strong> Define your own exception class by subclassing Exception.</em>'''

class NoOffersApplied(Exception):
    pass
try:
    total_spend = float(input("Enter your total spend :--"))
    offers_applied = int(input("Enter your number of offers appiled:--"))
    if offers_applied==0:
        raise NoOffersApplied
    average_cashback = total_spend/offers_applied
    print("The average cashback per offer is :-",average_cashback)
except NoOffersApplied:
    print("Error : No offer were applied .cashbackcannot be calculated ")

finally :
    print("Thank you for using the cashback pyment calculator")
# Out:
# Thank you for using the cashback pyment calculator
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 18
#      14 except NoOffersApplied:
#      15     print("Error : No offer were applied .cashbackcannot be calculated ")
#      16
#      17 finally :
# ---> 18     print("Thank you for using the cashback pyment calculator")
#      19
#      20
#      21
#
# ValueError: could not convert string to float: ''

# %%
'''4.Refactor the following buggy code to handle exceptions correctly so it never crashes and always prints 'Thank you for using the calculator' at the end, 
even if an exception occurs:<br><br>def calculate_average_rating(total_rating, num_reviews):<br> return total_rating / num_reviews<br>
print(calculate_average_rating(500, 0))'''
try :
    total_rating = 50
    num_reviews = 0
    average_rating = total_rating/num_reviews
    print("The average rating of following buggy")
except ZeroDivisionError:
    print("Error: number of reviews cannot be zero")
finally :
    print("Thank you for using the calculator")
# Out:
# Error: number of reviews cannot be zero
# Thank you for using the calculator

# %%
'''5.Write a function called safe_divide_for_zomato that takes two numbers (bill amount and number of people), uses try, except, else, and finally to divide 
the bill and print the result, print a custom error if division by zero, and always print 'Split calculation done' at the end.'''
def safe_divide_for_zomato(bill_amount,number_people):

    try :
        split_amount = bill_amount/number_people
    except ZeroDivisionError:
        print("Error:Number of people cannot be zero.")
    else:
        print("Each person should pay :--",split_amount)
    finally:
        print("split calculation is done")

safe_divide_for_zomato(1200,4)
print()
# Out:
# Each person should pay :-- 300.0
# split calculation is done
